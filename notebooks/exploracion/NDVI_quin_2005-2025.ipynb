# %%
# Librerías
import pandas as pd
from pathlib import Path
import ee
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Librerías
#       2 import pandas as pd
# ----> 3 import geopandas as gpd
#       4 from pathlib import Path
#       5 import ee
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# Log Google Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-cafe-494102')

# %%
# Enrutamiento de archivos
BASE_DIR = Path.cwd().parents[1]

ruta_municipios = BASE_DIR / "data" / "processed" / "municipios.csv"
ruta_salida = BASE_DIR / "data" / "raw" / "ndvi"
ruta_salida.mkdir(parents=True, exist_ok=True)

archivo_salida = ruta_salida / "ndvi_municipal_mod13q1_2005_2025.csv"

# Lectura municipios
municipios = pd.read_csv(ruta_municipios)
municipios.head()
