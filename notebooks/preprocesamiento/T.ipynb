# %%
# librerías
import os as os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
BASE_DIR = Path.cwd().parents[1]
ruta_nc = BASE_DIR / "data" / "raw" / "TemperauraSuperficialSueloCaldas.nc"

ruta_nc
# Out:
# PosixPath('/home/ddayann/proyectos/Coffe/proyecto_aplicado_en_analitica_de_datos/data/raw/TemperauraSuperficialSueloCaldas.nc')

# %%
import xarray as xr
ds = xr.open_dataset(ruta_nc)
ds
# Out:
# <xarray.Dataset> Size: 4kB
# Dimensions:                           (time: 126, bnds: 2)
# Coordinates:
#   * time                              (time) datetime64[ns] 1kB 2015-01-01 .....
# Dimensions without coordinates: bnds
# Data variables:
#     GLDAS_NOAH10_M_2_1_AvgSurfT_inst  (time) float32 504B ...
#     datamonth                         (time) int32 504B ...
#     time_bnds                         (time, bnds) datetime64[ns] 2kB ...
# Attributes: (12/23)
#     Conventions:                 CF-1.4
#     start_time:                  2015-01-01T00:00:00Z
#     end_time:                    2025-07-01T00:00:00Z
#     temporal_resolution:         monthly
#     NCO:                         netCDF Operators version 5.0.6 (Homepage = h...
#     nco_openmp_thread_number:    1
#     ...                          ...
#     plot_hint_y_axis_label:      K
#     history:                     Sat Nov 15 16:54:07 2025: ncatted -a plot_hi...
# ...
